# %%
import numpy as np
import matplotlib.pyplot as plt

# Input-Output Pairs
pairs = [
    (100, 0),
    (140, 6),
    (500, 16),
    (1000, 36),
    (2000, 43),
    (5000, 62),
    (7499, 78),
    (10000, 93),
    (15000, 110),
    (20000, 128),
    (30000, 159)
]

# Separate pairs into x and y values
x, y = zip(*pairs)

# Fit a polynomial of degree n (adjust as needed)
degree = 3  # You can change the degree for a better fit
coefficients = np.polyfit(x, y, degree)

# Create a polynomial function from the coefficients
polynomial = np.poly1d(coefficients)

# Print the coefficients
print("Coefficients:", coefficients)

# Print the polynomial equation
print("Polynomial equation:")
print(polynomial)

# Optional: Plotting the data and the fitted polynomial
x_line = np.linspace(min(x), max(x), 100)
y_line = polynomial(x_line)

plt.scatter(x, y, color='red', label='Data points')
plt.plot(x_line, y_line, label='Fitted polynomial', color='blue')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Polynomial Fit to Data')
plt.legend()
plt.grid()
plt.show()
# Out:
# Coefficients: [ 1.03239807e-11 -5.88271180e-07  1.33559834e-02  9.72754328e+00]
# Polynomial equation:
#            3             2
# 1.032e-11 x - 5.883e-07 x + 0.01336 x + 9.728
